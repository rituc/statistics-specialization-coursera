# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("~/workspace/statistics-coursera/movies.csv")

# %%
df = data.drop([data.columns[0]], axis=1)

# %%
df.columns
# Out:
# Index([u'title', u'title_type', u'genre', u'runtime', u'mpaa_rating',
#        u'studio', u'thtr_rel_year', u'thtr_rel_month', u'thtr_rel_day',
#        u'dvd_rel_year', u'dvd_rel_month', u'dvd_rel_day', u'imdb_rating',
#        u'imdb_num_votes', u'critics_rating', u'critics_score',
#        u'audience_rating', u'audience_score', u'best_pic_nom', u'best_pic_win',
#        u'best_actor_win', u'best_actress_win', u'best_dir_win', u'top200_box',
#        u'director', u'actor1', u'actor2', u'actor3', u'actor4', u'actor5',
#        u'imdb_url', u'rt_url'],
#       dtype='object')

# %%
df.shape
# Out:
# (651, 32)

# %%
df.head()
# Out:
#                   title    title_type   genre  runtime mpaa_rating  \
# 0           Filly Brown  Feature Film   Drama     80.0           R
# 1              The Dish  Feature Film   Drama    101.0       PG-13
# 2   Waiting for Guffman  Feature Film  Comedy     84.0           R
# 3  The Age of Innocence  Feature Film   Drama    139.0          PG
# 4           Malevolence  Feature Film  Horror     90.0           R
#
#                      studio  thtr_rel_year  thtr_rel_month  thtr_rel_day  \
# 0       Indomina Media Inc.           2013               4            19
# 1     Warner Bros. Pictures           2001               3            14
# 2    Sony Pictures Classics           1996               8            21
# 3         Columbia Pictures           1993              10             1
# 4  Anchor Bay Entertainment           2004               9            10
#
#    dvd_rel_year                        ...                         \
# 0        2013.0                        ...
# ...

# %% [markdown]
# ## Score
# * mpaa_rating
# * imdb_rating
# * imdb_num_votes
# * critics_rating
# * critics_score
# * audience_rating
# * audience_score
#
# ## Win
# * best_pic_nom
# * best_pic_win
# * best_actor_win
# * best_actress_win
# * best_dir_win
# * top200_box
#
# ## Movie Features
# * title_type
# * genre
# * runtime
#
# ## Movie Release Date
# * thtr_rel_year
# * thtr_rel_month
# * thtr_rel_day
# * dvd_rel_year
# * dvd_rel_month
# * dvd_rel_day
#
#
#
# ## Others
# * studio
# * director
# * actor1
# * actor2
# * actor3
# * actor4
# * actor5

# %%
score_cols = ["mpaa_rating",
"imdb_rating",
"imdb_num_votes",
"critics_rating",
'critics_score',
"audience_rating",
"audience_score"]

# %%
df["mpaa_rating"].value_counts()
# Out:
# R          329
# PG-13      133
# PG         118
# Unrated     50
# G           19
# NC-17        2
# Name: mpaa_rating, dtype: int64

# %%
# df["imdb_rating"].value_counts()

# %%
df["imdb_rating"].describe()
# Out:
# count    651.000000
# mean       6.493088
# std        1.084747
# min        1.900000
# 25%        5.900000
# 50%        6.600000
# 75%        7.300000
# max        9.000000
# Name: imdb_rating, dtype: float64

# %%
df["title_type"].value_counts()
# Out:
# Feature Film    591
# Documentary      55
# TV Movie          5
# Name: title_type, dtype: int64

# %%
sns.boxplot(x="title_type", y="imdb_rating", data=df)

# %%
df["top200_box"].value_counts()
# Out:
# no     636
# yes     15
# Name: top200_box, dtype: int64

# %%
df[["imdb_rating", "imdb_num_votes", "critics_score", "audience_score", "runtime"]].describe()
# Out:
#        imdb_rating  imdb_num_votes  critics_score  audience_score     runtime
# count   651.000000      651.000000     651.000000      651.000000  650.000000
# mean      6.493088    57532.983103      57.688172       62.362519  105.821538
# std       1.084747   112124.386910      28.402971       20.222624   19.445047
# min       1.900000      180.000000       1.000000       11.000000   39.000000
# 25%       5.900000     4545.500000      33.000000       46.000000   92.000000
# 50%       6.600000    15116.000000      61.000000       65.000000  103.000000
# 75%       7.300000    58300.500000      83.000000       80.000000  115.750000
# max       9.000000   893008.000000     100.000000       97.000000  267.000000

# %%
df[df["imdb_rating"] == 9.0]
# Out:
#                       title    title_type               genre  runtime  \
# 351  The Godfather, Part II  Feature Film  Mystery & Suspense    202.0
#
#     mpaa_rating              studio  thtr_rel_year  thtr_rel_month  \
# 351           R  Paramount Pictures           1974              12
#
#      thtr_rel_day  dvd_rel_year  \
# 351            20        2005.0
#
#                          ...                        best_dir_win  top200_box  \
# 351                      ...                                 yes          no
#
#                  director     actor1          actor2         actor3  \
# 351  Francis Ford Coppola  Al Pacino  Robert De Niro  Robert Duvall
#
#            actor4       actor5                              imdb_url  \
# 351  Diane Keaton  Talia Shire  http://www.imdb.com/title/tt0071562/
#
#                                             rt_url
# 351  //www.rottentomatoes.com/m/godfather_part_ii/
#
# [1 rows x 32 columns]

# %%
df["genre"].value_counts()
# Out:
# Drama                        305
# Comedy                        87
# Action & Adventure            65
# Mystery & Suspense            59
# Documentary                   52
# Horror                        23
# Other                         16
# Art House & International     14
# Musical & Performing Arts     12
# Animation                      9
# Science Fiction & Fantasy      9
# Name: genre, dtype: int64

# %%
g = sns.boxplot(x="genre", y="imdb_rating", data=df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
df["audience_rating"].value_counts()
# Out:
# Upright    376
# Spilled    275
# Name: audience_rating, dtype: int64

# %%
g = sns.boxplot(x="genre", y="audience_score", data=df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
corr_df = df.corr()

# %%
corr_df
# Out:
#                  runtime  thtr_rel_year  thtr_rel_month  thtr_rel_day  \
# runtime         1.000000      -0.104377        0.220987      0.037396
# thtr_rel_year  -0.104377       1.000000       -0.000507      0.107400
# thtr_rel_month  0.220987      -0.000507        1.000000      0.116228
# thtr_rel_day    0.037396       0.107400        0.116228      1.000000
# dvd_rel_year   -0.081902       0.660465       -0.009989      0.041322
# dvd_rel_month  -0.033309       0.036678       -0.168612     -0.025531
# dvd_rel_day     0.024235      -0.003763        0.028240      0.001797
# imdb_rating     0.268240      -0.030003        0.072278      0.021891
# imdb_num_votes  0.347215       0.155906        0.106326      0.067976
# critics_score   0.172499      -0.080785        0.032404      0.013689
# audience_score  0.180963      -0.054079        0.032690      0.019221
#
#                 dvd_rel_year  dvd_rel_month  dvd_rel_day  imdb_rating  \
# ...

# %%
sns.heatmap(corr_df, xticklabels=corr_df.columns, yticklabels=corr_df.columns, annot=True)

# %%
g = sns.boxplot(x="genre", y="runtime", data=df)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
sns.regplot(x="runtime", y="audience_score", data=df)

# %%
sns.distplot(df["audience_score"])

# %%
sns.pairplot(df[score_cols])

# %%
sns.pairplot(df[["audience_score", "genre"]])

# %%
g = sns.FacetGrid(df, col='audience_score', hue="genre", palette="Set1")

# %%
g = sns.FacetGrid(df, col="audience_score" ,row="genre")
g = g.map(sns.distplot, "audience_score")

# %%
# g = (g.map(sns.distplot, "audience_score", hist=False, rug=True))
plt.figure(figsize=(10, 10))
g = sns.FacetGrid(df, hue="genre")
g = g.map(sns.distplot, "audience_score")

# %%
sns.pairplot(df[["audience_score", "genre"]], hue="genre", size=5)

# %%
genre_df = pd.get_dummies(df, columns= ["genre"] )

# %%
genre_df.columns
# Out:
# Index([u'title', u'title_type', u'runtime', u'mpaa_rating', u'studio',
#        u'thtr_rel_year', u'thtr_rel_month', u'thtr_rel_day', u'dvd_rel_year',
#        u'dvd_rel_month', u'dvd_rel_day', u'imdb_rating', u'imdb_num_votes',
#        u'critics_rating', u'critics_score', u'audience_rating',
#        u'audience_score', u'best_pic_nom', u'best_pic_win', u'best_actor_win',
#        u'best_actress_win', u'best_dir_win', u'top200_box', u'director',
#        u'actor1', u'actor2', u'actor3', u'actor4', u'actor5', u'imdb_url',
#        u'rt_url', u'genre_Action & Adventure', u'genre_Animation',
#        u'genre_Art House & International', u'genre_Comedy',
#        u'genre_Documentary', u'genre_Drama', u'genre_Horror',
#        u'genre_Musical & Performing Arts', u'genre_Mystery & Suspense',
#        u'genre_Other', u'genre_Science Fiction & Fantasy'],
#       dtype='object')

# %%
genre_cols = ["genre_" + i for i in df["genre"].unique()]
